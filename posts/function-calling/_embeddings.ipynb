# %%
from openai import OpenAI
import pandas as pd
import numpy as np
from slugify import slugify
from sklearn.metrics.pairwise import cosine_similarity

from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/nealcaren/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
client = OpenAI()

def embed_text(text):
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return response.data[0].embedding

def embed_texts(text):
    response = client.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return [_.embedding for _ in response.data]

# %%
paragraphs = []

file_path = "/Users/nealcaren/Documents/GitHub/a-century-of-negro-migration/chapters/"
for i in range(1, 10):
    fn = f"chapter-0{i}.md"
    with open(f"{file_path}{fn}", "r") as infile:
        md = infile.read()
        paragraphs_text = md.splitlines()
        paragraphs_text = [line for line in paragraphs_text if line.strip() != '']
        paragraphs_text = [line for line in paragraphs_text if line[:2]!='[^']
        paragraphs_text = [line for line in paragraphs_text if len(line.split())>1]
        
        for idx, paragraph in enumerate(
            paragraphs_text, start=1
        ):  # start=1 to start numbering from 1
            paragraphs.append(
                {"text": paragraph, "chapter": i, "paragraph_number": idx, "filename": fn}
            )

# Convert the list of dictionaries into a DataFrame
df = pd.DataFrame(paragraphs)

# %%
df.sample(3)
# Out:
#                                                   text  chapter  \
# 230  John M. Langston was taken to Ohio and educate...        6
# 191  This progress of the Negroes in the North was ...        5
# 58   | Maine                |           1,356 |    ...        2
#
#      paragraph_number       filename
# 230                37  chapter-06.md
# 191                30  chapter-05.md
# 58                 41  chapter-02.md

# %%
df['embeddings'] = df['text'].apply(embed_text)

# %%
def best_match(df, text_string):
    """
    This function computes the cosine similarity between a given embedding and all the embeddings in the DataFrame.
    It returns the row with the highest similarity score.
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing the text embeddings
    embedding (list): The embedding vector to match against the DataFrame's embeddings
    
    Returns:
    pd.Series: The row from the DataFrame that best matches the given embedding
    """
    
    embedding = embed_text(text_string)
    # Convert the embeddings list to a 2D numpy array if they are not already
    df['embeddings'] = df['embeddings'].apply(lambda x: np.array(x))
    embeddings_matrix = np.stack(df['embeddings'].values)

    # Normalize the input embedding and embeddings matrix for cosine similarity
    embedding_normalized = embedding / np.linalg.norm(embedding)
    embeddings_matrix_normalized = embeddings_matrix / np.linalg.norm(embeddings_matrix, axis=1)[:, np.newaxis]
    
    # Calculate the cosine similarities
    similarities = cosine_similarity([embedding_normalized], embeddings_matrix_normalized)

    # Get the index of the most similar embedding
    most_similar_index = np.argmax(similarities)
    return most_similar_index

def best_location(df, text_string):
    most_similar_index = best_match(df, text_string)
    # Return the corresponding row from the DataFrame
    sdf = df.iloc[most_similar_index].to_frame().T
    sdf['sentences'] = sdf['text'].apply(sent_tokenize)
    sdf = sdf.explode('sentences')
    sdf['embeddings'] = embed_texts(sdf['text'].values)
    most_similar_index = best_match(sdf, text_string)
    sdf['slug'] = slug
    
    return sdf.iloc[most_similar_index]
    return sdf

# %%
idf.sample(3)
# Out:
#                                                   text  paragraph_number  \
# 61                    Conventions of Negroes, 99-100                  62
# 266  Turner, Bishop H. M., interested in sending Ne...               267
# 217  Reconstruction, promoted to an extent by Negro...               218
#
#                       entry  \
# 61   Conventions of Negroes
# 266    Turner, Bishop H. M.
# 217          Reconstruction
#
#                                       text_minus_entry  \
# 61                                            99-100
# 266       interested in sending Negroes to Africa, 157
# 217  promoted to an extent by Negro natives of Nort...
#
#                                                md_text
# 61   Conventions of Negroes, [99-100](chapter-5.md#...
# 266  Turner, Bishop H. M., interested in sending Ne...
# 217  Reconstruction, promoted to an extent by Negro...

# %%
b = best_location(df[df['chapter'] == 5].copy(), "Conventions of Negroes")

# %%
b['text']
# Out:
# 'The Negroes in the North had not only shown their ability to rise in the economic world when properly encouraged but had begun to exhibit power of all kinds. There were Negro inventors, a few lawyers, a number of physicians and dentists, many teachers, a score of intelligent preachers, some scholars of note, and even successful blacks in the finer arts. Some of these, with Frederick Douglass as the most influential, were also doing creditable work in journalism with about thirty newspapers which had developed among the Negroes as weapons of defense.[^40]'

# %%
index_fn = f'/Users/nealcaren/Library/CloudStorage/Dropbox/gpt-ocr/index.md'
with open(index_fn, 'r') as infile:
    index_md = infile.read()

# %%
paragraphs = []
paragraphs_text = index_md.splitlines()
paragraphs_text = [line for line in paragraphs_text if line.strip() != '']
paragraphs_text = [line for line in paragraphs_text if line[:2]!='[^']
paragraphs_text = [line for line in paragraphs_text if line[:2]!='# ']
paragraphs_text = [line for line in paragraphs_text if '[' not in line]
paragraphs_text = [line for line in paragraphs_text if '::' not in line]
paragraphs_text = [line for line in paragraphs_text if '<!' not in line]

paragraphs_text = [line for line in paragraphs_text if len(line.split())>1]
        
for idx, paragraph in enumerate(
            paragraphs_text, start=1
        ):  # start=1 to start numbering from 1
            paragraphs.append(
                {"text": paragraph, "paragraph_number": idx, }
            )

# %%
paragraphs[0]
# Out:
# {'text': 'Adams, Henry, leader of the exodus to Kansas, 135  ',
#  'paragraph_number': 1}

# %%
import re

def extract_entry_name(line):
    # Regular expression pattern to match entry names that start with a capital letter and end before a comma followed by a lowercase letter
    pattern = re.compile(r"^[A-Z].+?(?=(,\s[a-z]|,?\s?\d))")

    # Find the match in the line
    match = pattern.search(line)

    # Return the entry name if found, otherwise None
    return match.group(0).strip() if match else 'None'

# %%
idf=pd.DataFrame(paragraphs)

# %%
idf['entry'] = idf['text'].apply(extract_entry_name)

# %%
idf.to_clipboard()

# %%
idf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   text              296 non-null    object
#  1   paragraph_number  296 non-null    int64
#  2   entry             296 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.1+ KB

# %%
idf['text_minus_entry'] = idf.apply(lambda row: row['text'][len(row['entry']) + 2:], axis=1)

# %%
idf
# Out:
#                                                   text  paragraph_number  \
# 0    Adams, Henry, leader of the exodus to Kansas, ...                 1
# 1                 Akron, friends of fugitives in, 30                   2
# 2                   Alton Telegraph, comment of, 118                   3
# 3    Anderson, promoter of settling of Negroes in J...                 4
# 4    Anti-slavery, leaders of the movement, became ...                 5
# ..                                                 ...               ...
# 291  Wickham, executor of Samuel Gist, settled Gist...               292
# 292  Wilberforce University, established at a slave...               293
# 293    Wilcox, Samuel T., a merchant of Cincinnati, 95               294
# 294     Yankees, comment of, on Negro labor, 115-116                 295
# 295  York, Negroes of, 24; trouble with the Negroes...               296
#
#                       entry                                   text_minus_entry
# 0              Adams, Henry              leader of the exodus to Kansas, 135
# 1                     Akron                      friends of fugitives in, 30
# 2           Alton Telegraph                                  comment of, 118
# 3                  Anderson   promoter of settling of Negroes in Jamaica, 79
# 4              Anti-slavery  leaders of the movement, became more helpful t...
# ..                      ...                                                ...
# 291                 Wickham  executor of Samuel Gist, settled Gist's Negroe...
# 292  Wilberforce University            established at a slave settlement, 27
# 293       Wilcox, Samuel T.                       a merchant of Cincinnati, 95
# 294                 Yankees              comment of, on Negro labor, 115-116
# 295        York, Negroes of                24; trouble with the Negroes of, 44
#
# [296 rows x 4 columns]

# %%
def get_chapter_from_page(page_number):
    # Define the ranges of page numbers for each chapter
    chapters = {
        1: range(1, 18),        # Chapter I: Pages 1-17
        2: range(18, 39),       # Chapter II: Pages 18-38
        3: range(39, 61),       # Chapter III: Pages 39-60
        4: range(61, 81),       # Chapter IV: Pages 61-80
        5: range(81, 101),      # Chapter V: Pages 81-100
        6: range(101, 126),     # Chapter VI: Pages 101-125
        7: range(126, 147),     # Chapter VII: Pages 126-146
        8: range(147, 167),     # Chapter VIII: Pages 147-166
        9: range(167, 193)      # Chapter IX: Pages 167-192
        # Note: Bibliography and Index are not counted as chapters
    }

    # Convert the page number to an integer
    page_number = str(page_number).replace('-','–')
    page_number = int(page_number.split('–')[0])

    # Find the chapter that the page number falls into
    for chapter, pages in chapters.items():
        if page_number in pages:
            return chapter

    # If the page number is not in any chapter range, return None
    return None

# Test the function with the provided example
get_chapter_from_page("111-119")
# Out:
# 6

# %%
def process_string(input_strings):
    process_text = []
    for input_string in input_strings.split('; '):
        # Extract the last part of the string that contains the page number or range
            page_number_or_range = input_string.split(', ')[-1].strip()

            text_without_page_number = input_string.replace(page_number_or_range,'')
            print(page_number_or_range)
            # Get the chapter number using the page number or range
            chapter_number = get_chapter_from_page(page_number_or_range)

            # Slugify the rest of the string
            slugified_text = slugify(text_without_page_number)

            # Format the new Markdown link
            markdown_link = f'[{page_number_or_range}](chapter-{chapter_number}.md#{slugified_text})'

            # Replace the page number or range at the end of the input string with the new Markdown link
            process_text.append(input_string.replace(page_number_or_range,'') + markdown_link)

    return '; '.join(process_text).replace('   ',' ')

# %%
process_string('Adams, Henry, leader of the exodus to Kansas, 135')
# Out:
# 135
# 'Adams, Henry, leader of the exodus to Kansas, [135](chapter-7.md#adams-henry-leader-of-the-exodus-to-kansas)'

# %%
idf['md_text'] = idf['text'].apply(process_string)
# Out:
# 135
# 30
# 118
# 79
# 35
# 3
# 191
# 31-34
# 146
# 120
# 95
# 95
# 79
# 90
# 7
# 7
# 9
# 61
# 24
# 79
# 35
# 57
# 57
# 59-60
# 169
# 31
# 78
# 95
# 10
# 61
# 12
# 68
# 30
# 33-34
# 25
# 30
# 17
# 102
# 112
# 28-29
# 29
# 143
# 49
# 35
# 36
# 13
# 14
# 49
# 124
# 87
# 89
# 124
# 30
# 56-58
# 92-95
# 88
# 63
# 14-16
# 114
# 29
# 68-80
# 11
# 79
# 90
# 125
# 4
# 10
# 63
# 66
# 65-66
# 69-70
# 70
# 61-80
# 63
# 148
# 70-74
# 30
# 6
# 115
# 188-189
# 2
# 49-50
# 99-100
# 97
# 135
# 49
# 134
# 6
# 63
# 119
# 97
# 154
# 79-80
# 44
# 39
# 27
# 30
# 35
# 54-55
# 59-60
# 96
# 12
# 189
# 36-38
# 98
# 164
# 138-139
# 87
# 120
# 120
# 110-111
# 133-134
# 184-185
# 155
# 30
# 124
# 30
# 68-71
# 188
# 167-192
# 172-176
# 172
# 175
# 176
# 177
# 179-180
# 180-181
# 134-136
# 183
# 119
# 111
# 119
# 167-169
# 137
# 6
# 89
# 111–112
# 65–66
# 67–68
# 79
# 7
# 11
# 12
# 30
# 82
# 41
# 30
# 84
# 2
# 41
# 31
# 26–27
# 82
# 124
# 94
# 25
# 90
# 95–96
# 103
# 103
# 109
# 139–141
# 124
# 27
# 147
# 89
# 102
# 95
# 26
# 24
# 44
# 90
# 85
# 79–80
# 1
# 92
# 79
# 124
# 109
# 54
# 50
# 14
# 15
# 172-173
# 143
# 53
# 24
# 14
# 15
# 58
# 58-59
# 146
# 106
# 156
# 41
# 82
# 78-79
# 8
# 9
# 9-10
# 1
# 92
# 102
# 90
# 141
# 142
# 142-143
# 6
# 20
# 39
# 10
# 63
# 75-77
# 128
# 173-174
# 79
# 134
# 131-132
# 124
# 57
# 22
# 103
# 7
# 120
# 134
# 106
# 25
# 7
# 7
# 35
# 156
# 156
# 102
# 39
# 84
# 2
# 2
# 63
# 93
# 56
# 27
# 27
# 54
# 147–166
# 166
# 160
# 161
# 162
# 163
# 163
# 135
# 120
# 134
# 106
# 6
# 148
# 18
# 18
# 101–124
# 101
# 91
# 128–129
# 1–2
# 98
# 126-129
# 11
# 160
# 151
# 157
# 165
# 121
# 123
# 94–95
# 94
# 2
# 2
# 2
# 31
# 48
# 40
# 48–49
# 39–40
# 22
# 2
# 100
# 83
# 3
# 3
# 3
# 186
# 186–187
# 189
# 157
# 16
# 17
# 17
# 49
# 135
# 190–191
# 51
# 51
# 51–53
# 57
# 144
# 144–145
# 4
# 4
# 5
# 5
# 8
# 18
# 1
# 113
# 49
# 97
# 20
# 42
# 42
# 42
# 45
# 40
# 2
# 21
# 40
# 84
# 88–90
# 154
# 24
# 44
# 44
# 44
# 44
# 45–48
# 88–90
# 89
# 102
# 125
# 7
# 30
# 12
# 12
# 12
# 47
# 87
# 181
# 181–183
# 153
# 78
# 30
# 57
# 92
# 6
# 148-150
# 19
# 18-38
# 34
# 82-83
# 82-84
# 63
# 26
# 20
# 123
# 80
# 105-106
# 106
# 155
# 106
# 112
# 113
# 116
# 117-118
# 6
# 136-137
# 2
# 90
# 97-98
# 90
# 11
# 30
# 141
# 24
# 28
# 102
# 31
# 87
# 121
# 157
# 24
# 79
# 124
# 135
# 4-5
# 7
# 7
# 5
# 5
# 7
# 86–87
# 89
# 2
# 185
# 121–123
# 32–33
# 27
# 113
# 91
# 89–90
# 6
# 81–101
# 39–40
# 41
# 48
# 177
# 120
# 66
# 106
# 95
# 118
# 82
# 190–192
# 77–88
# 78
# 157
# 25
# 7
# 7
# 126–130
# 130
# 131
# 132
# 153
# 48
# 111–119
# 121–123
# 2
# 135
# 6
# 39
# 18–19
# 2
# 106
# 138
# 63
# 105
# 160
# 25-26
# 2
# 23
# 79
# 11
# 68
# 146
# 22-23
# 124
# 127-128
# 79
# 2
# 25
# 27
# 95
# 115-116
# 24
# 44

# %%
for _, row in idf.iterrows():
    index_md = index_md.replace(row['text'], row['md_text'])

print(index_md)
# Out:
# # INDEX
#
# Adams, Henry, leader of the exodus to Kansas, [135](chapter-7.md#adams-henry-leader-of-the-exodus-to-kansas)
# Akron, friends of fugitives in, [30](chapter-2.md#akron-friends-of-fugitives-in)
# Alton Telegraph, comment of, [118](chapter-6.md#alton-telegraph-comment-of)
# Anderson, promoter of settling of Negroes in Jamaica, [79](chapter-4.md#anderson-promoter-of-settling-of-negroes-in-jamaica)
# Anti-slavery, leaders of the movement, became more helpful to the refugees, 34, [35](chapter-2.md#anti-slavery-leaders-of-the-movement-became-more-helpful-to-the-refugees-34)
# Anti-slavery sentiment, of two kinds, [3](chapter-1.md#anti-slavery-sentiment-of-two-kinds)
# American Federation of Labor, attitude of, toward Negro labor, [191](chapter-9.md#american-federation-of-labor-attitude-of-toward-negro-labor)
# Appalachian highland, settlers of, aided fugitives, [31-34](chapter-2.md#appalachian-highland-settlers-of-aided-fugitives); exodus of Negroes to, [146](chapter-7.md#exodus-of-negroes-to)
# Arkansas, drain of laborers to, [120](chapter-6.md#arkansas-drain-of-laborers-to)
#
# Ball, J. P., a contractor, [95](chapter-5.md#ball-j-p-a-contractor)
# Ball, Thomas, a contractor, [95](chapter-5.md#ball-thomas-a-contractor)
# Barclay, interest of, in the sending of Negroes to Jamaica, [79](chapter-4.md#barclay-interest-of-in-the-sending-of-negroes-to-jamaica)
# Barrett, Owen A., discoverer of a remedy, [90](chapter-5.md#barrett-owen-a-discoverer-of-a-remedy)
# Bates, owner of slaves at St. Genevieve, [7](chapter-1.md#bates-owner-of-slaves-at-st-genevieve)
# Beauvais, owner of slaves, Upper Louisiana, [7](chapter-1.md#beauvais-owner-of-slaves-upper-louisiana)
# Benezet, Anthony, plan of, to colonize Negroes in West, [9](chapter-1.md#benezet-anthony-plan-of-to-colonize-negroes-in-west); interest of, in settling Negroes in the West, [61](chapter-4.md#interest-of-in-settling-negroes-in-the-west)
# Berlin Cross Roads, Negroes of, [24](chapter-2.md#berlin-cross-roads-negroes-of)
# Bibb, Henry, interest of, in colonization, [79](chapter-4.md#bibb-henry-interest-of-in-colonization)
#
# Birney, James G., promoter of the migration of the Negroes, [35](chapter-2.md#birney-james-g-promoter-of-the-migration-of-the-negroes); press of, destroyed by mob in Cincinnati, [57](chapter-3.md#press-of-destroyed-by-mob-in-cincinnati)
# Black Friday, riot of, in Portsmouth, [57](chapter-3.md#black-friday-riot-of-in-portsmouth)
# Blackburn, Thornton, a fugitive claimed in Detroit, [59-60](chapter-3.md#blackburn-thornton-a-fugitive-claimed-in-detroit)
# Boll weevil, a cause of migration, [169](chapter-9.md#boll-weevil-a-cause-of-migration)
# Boston, friends of fugitives in, [31](chapter-2.md#boston-friends-of-fugitives-in)
# Boyce, Stanbury, went with his father to Trinidad in the fifties, [78](chapter-4.md#boyce-stanbury-went-with-his-father-to-trinidad-in-the-fifties)
# Boyd, Henry, a successful mechanic in Cincinnati, [95](chapter-5.md#boyd-henry-a-successful-mechanic-in-cincinnati)
# Brannagan, Thomas, advocate of colonizing the Negroes in the West, [10](chapter-1.md#brannagan-thomas-advocate-of-colonizing-the-negroes-in-the-west); interest of, in settling Negroes in the West, [61](chapter-4.md#interest-of-in-settling-negroes-in-the-west)
# Brisot de Warville, observations of, on Negroes in the West, [12](chapter-1.md#brisot-de-warville-observations-of-on-negroes-in-the-west)
# British Guiana, attractive to free Negroes, [68](chapter-4.md#british-guiana-attractive-to-free-negroes)
# Brooklyn, Illinois, a Negro community, [30](chapter-2.md#brooklyn-illinois-a-negro-community)
# Brown, John, in the Appalachian highland, [33-34](chapter-2.md#brown-john-in-the-appalachian-highland)
# Brown County, Ohio, Negroes in, [25](chapter-2.md#brown-county-ohio-negroes-in)
# Buffalo, friends of fugitives in, [30](chapter-2.md#buffalo-friends-of-fugitives-in)
# Butler, General. holds Negroes as contraband, [17](chapter-1.md#butler-general-holds-negroes-as-contraband); policy of, followed by General Wood and General Banks, [102](chapter-6.md#policy-of-followed-by-general-wood-and-general-banks)
#
# Cairo, Illinois, an outlet for the refugees, [112](chapter-6.md#cairo-illinois-an-outlet-for-the-refugees)
# Calvin Township, Cass County, Michigan, a Negro community, [28-29](chapter-2.md#calvin-township-cass-county-michigan-a-negro-community); note on progress of, [29](chapter-2.md#note-on-progress-of)
# Campbell, Sir George, comment on condition of Negroes in Kansas City, [143](chapter-7.md#campbell-sir-george-comment-on-condition-of-negroes-in-kansas-city)
# Canaan, New Hampshire, break-up of school of, admitting Negroes, [49](chapter-3.md#canaan-new-hampshire-break-up-of-school-of-admitting-negroes)
# Canada, the migration of Negroes to, [35](chapter-2.md#canada-the-migration-of-negroes-to); settlements in, [36](chapter-2.md#settlements-in)
# Canadians, supply of slaves of, [13](chapter-1.md#canadians-supply-of-slaves-of); prohibited the importation of slaves, [14](chapter-1.md#prohibited-the-importation-of-slaves)
# Canterbury, people of, imprison Prudence Crandall because she taught Negroes, [49](chapter-3.md#canterbury-people-of-imprison-prudence-crandall-because-she-taught-negroes)
# Cardoza, F. L., return of from Edinburgh to South Carolina, [124](chapter-6.md#cardoza-f-l-return-of-from-edinburgh-to-south-carolina)
# Cassey, Joseph C., a lumber merchant, [87](chapter-5.md#cassey-joseph-c-a-lumber-merchant)
# Cassey, Joseph, a broker in Philadelphia, [89](chapter-5.md#cassey-joseph-a-broker-in-philadelphia)
# Chester, T. Morris, went from Pittsburgh to settle in Louisiana, [124](chapter-6.md#chester-t-morris-went-from-pittsburgh-to-settle-in-louisiana)
# Cincinnati, friends of fugitives in, [30](chapter-2.md#cincinnati-friends-of-fugitives-in); mobs, [56-58](chapter-3.md#mobs); successful Negroes of, [92-95](chapter-5.md#successful-negroes-of)
# Clark, Edward V., a jeweler, [88](chapter-5.md#clark-edward-v-a-jeweler)
# Clay, Henry, a colonizationist, [63](chapter-4.md#clay-henry-a-colonizationist)
# Code for indentured servants in West, note, [14-16](chapter-1.md#code-for-indentured-servants-in-west-note)
# Coffin, Levi, comment on the condition of the refugees, [114](chapter-6.md#coffin-levi-comment-on-the-condition-of-the-refugees)
# Coles, Edward, moved to Illinois to free his slaves, [29](chapter-2.md#coles-edward-moved-to-illinois-to-free-his-slaves); correspondence with Jefferson on slavery, [68-80](chapter-4.md#correspondence-with-jefferson-on-slavery)
# Colgate, Richard, master of James Wenyam who escaped to the West, [11](chapter-1.md#colgate-richard-master-of-james-wenyam-who-escaped-to-the-west)
# Collins, Henry M., interest of, in colonization, [79](chapter-4.md#collins-henry-m-interest-of-in-colonization); a real estate man in Pittsburgh, [90](chapter-5.md#a-real-estate-man-in-pittsburgh)
# Corbin, J. C., return of, from Chillicothe to Arkansas, [125](chapter-6.md#corbin-j-c-return-of-from-chillicothe-to-arkansas)
# Colonization proposed as a remedy for migration, [4](chapter-1.md#colonization-proposed-as-a-remedy-for-migration); in the West, 4, [10](chapter-1.md#in-the-west-4); organization of society of, [63](chapter-4.md#organization-of-society-of); failure to remove free Negroes, 64-65, [66](chapter-4.md#failure-to-remove-free-negroes-64-65); opposed by free people of color, [65-66](chapter-4.md#opposed-by-free-people-of-color); meetings of, in the interests of the West Indies, [69-70](chapter-4.md#meetings-of-in-the-interests-of-the-west-indies); impeded by the exodus to the West Indies, [70](chapter-4.md#impeded-by-the-exodus-to-the-west-indies); a remedy for migration, [61-80](chapter-4.md#a-remedy-for-migration)
# Colonization Society, organization of, [63](chapter-4.md#colonization-society-organization-of); renewed efforts of, [148](chapter-8.md#renewed-efforts-of)
# Colonizationists, opposition of, to the migration to the West Indies, [70-74](chapter-4.md#colonizationists-opposition-of-to-the-migration-to-the-west-indies)
# Columbia, Pa., friends of fugitives in, [30](chapter-2.md#columbia-pa-friends-of-fugitives-in)
# Compagnie de l’Occident in control of Louisiana, [6](chapter-1.md#compagnie-de-loccident-in-control-of-louisiana)
# Condition of fugitives in contraband camps, 103, 104, 107-108, 109-110, 114, [115](chapter-6.md#condition-of-fugitives-in-contraband-camps-103-104-107-108-109-110-114)
# Congested districts in the North, [188-189](chapter-9.md#congested-districts-in-the-north)
# Connecticut exterminated slavery, [2](chapter-1.md#connecticut-exterminated-slavery); law of, against teaching Negroes, [49-50](chapter-3.md#law-of-against-teaching-negroes)
# Conventions of Negroes, [99-100](chapter-5.md#conventions-of-negroes)
# Cook, Forman B., a broker, [97](chapter-5.md#cook-forman-b-a-broker)
# Crandall, A. W., interest in checking the exodus to Kansas, [135](chapter-7.md#crandall-a-w-interest-in-checking-the-exodus-to-kansas)
# Crandall, Prudence, imprisoned because she taught Negroes, [49](chapter-3.md#crandall-prudence-imprisoned-because-she-taught-negroes)
#
#
# Credit system, a cause of unrest, 129, 133, [134](chapter-7.md#credit-system-a-cause-of-unrest-129-133)
# Croazat, Antoine, as Governor of Louisiana, [6](chapter-1.md#croazat-antoine-as-governor-of-louisiana)
# Cuffé, Paul, an actual colonizationist, [63](chapter-4.md#cuffe-paul-an-actual-colonizationist)
#
# Davis, comment on freedmen's vagrancy, [119](chapter-6.md#davis-comment-on-freedmen-s-vagrancy)
# De Baptiste, Richard, father of, in Detroit, 28, [97](chapter-5.md#de-baptiste-richard-father-of-in-detroit-28)
# Debasement of the blacks after Reconstruction, [154](chapter-8.md#debasement-of-the-blacks-after-reconstruction)
# Delany, Martin R., interest of, in colonization, [79-80](chapter-4.md#delany-martin-r-interest-of-in-colonization)
# De Tocqueville, observation of, on the condition of free Negroes in the North, [44](chapter-3.md#de-tocqueville-observation-of-on-the-condition-of-free-negroes-in-the-north)
# Delaware, disfranchisement of Negroes in, [39](chapter-3.md#delaware-disfranchisement-of-negroes-in)
# Detroit, Negroes in, [27](chapter-2.md#detroit-negroes-in); friends of fugitives in, [30](chapter-2.md#friends-of-fugitives-in); a gateway to Canada, [35](chapter-2.md#a-gateway-to-canada); the Negro question in, [54-55](chapter-3.md#the-negro-question-in); mob of, rises against Negroes, [59-60](chapter-3.md#mob-of-rises-against-negroes); successful Negroes of, [96](chapter-5.md#successful-negroes-of)
# Dinwiddie, Governor, Fears of, as to servile insurrection, [12](chapter-1.md#dinwiddie-governor-fears-of-as-to-servile-insurrection)
# Diseases of Negroes in the North, [189](chapter-9.md#diseases-of-negroes-in-the-north)
# Distribution of intelligent blacks, [36-38](chapter-2.md#distribution-of-intelligent-blacks)
# Douglass, Frederick, the leading Negro journalist, [98](chapter-5.md#douglass-frederick-the-leading-negro-journalist); advice of, on staying in the South to retain political power, [164](chapter-8.md#advice-of-on-staying-in-the-south-to-retain-political-power); comment of, on exodus to Kansas, [138-139](chapter-7.md#comment-of-on-exodus-to-kansas)
# Downing, Thomas, owner of a restaurant, [87](chapter-5.md#downing-thomas-owner-of-a-restaurant)
# Drain of laborers to Mississippi and Louisiana, [120](chapter-6.md#drain-of-laborers-to-mississippi-and-louisiana); to Arkansas and Texas, [120](chapter-6.md#to-arkansas-and-texas)
#
# Eaton, John, work of, among the refugees, [110-111](chapter-6.md#eaton-john-work-of-among-the-refugees)
# Economic opportunities for the Negro in the North, [133-134](chapter-7.md#economic-opportunities-for-the-negro-in-the-north); economic opportunities for Negroes in the South, [184-185](chapter-9.md#economic-opportunities-for-negroes-in-the-south)
# Educational facilities, the lack of, [155](chapter-8.md#educational-facilities-the-lack-of)
# Elizabethtown, friends of fugitives in, [30](chapter-2.md#elizabethtown-friends-of-fugitives-in)
# Elliot, R. B., return of, from Boston to South Carolina, [124](chapter-6.md#elliot-r-b-return-of-from-boston-to-south-carolina)
# Elmira, friends of fugitives in, [30](chapter-2.md#elmira-friends-of-fugitives-in)
# Emancipation of the Negroes in the West Indies, the effect of, [68-71](chapter-4.md#emancipation-of-the-negroes-in-the-west-indies-the-effect-of)
# Epstein, Abraham, an authority on the Negro migrant in Pittsburgh, [188](chapter-9.md#epstein-abraham-an-authority-on-the-negro-migrant-in-pittsburgh)
# Exodus, the, during the World War, [167-192](chapter-9.md#exodus-the-during-the-world-war); causes, 167-171, [172-176](chapter-9.md#causes-167-171); efforts of the South to check it, [172](chapter-9.md#efforts-of-the-south-to-check-it); Negroes divided on it, [175](chapter-9.md#negroes-divided-on-it); whites divided on it, [176](chapter-9.md#whites-divided-on-it); unfortunate for the South, [177](chapter-9.md#unfortunate-for-the-south); probable results, [179-180](chapter-9.md#probable-results); will increase political power of Negro, [180-181](chapter-9.md#will-increase-political-power-of-negro); exodus of the Negroes to Kansas, [134-136](chapter-7.md#exodus-of-the-negroes-to-kansas)
#
# Fear of Negro domination to cease, [183](chapter-9.md#fear-of-negro-domination-to-cease)
# Ficklen, comment on freedmen's vagrancy, [119](chapter-6.md#ficklen-comment-on-freedmen-s-vagrancy)
# Fiske, A. S., work of, among the contrabands, [111](chapter-6.md#fiske-a-s-work-of-among-the-contrabands)
# Fleming, comment of, on freedmen's vagrancy, [119](chapter-6.md#fleming-comment-of-on-freedmen-s-vagrancy)
# Floods of the Mississippi, a cause of migration, [167-169](chapter-9.md#floods-of-the-mississippi-a-cause-of-migration)
# Foote, Ex-Governor of Mississippi, liberal measure of, presented to Vicksburg convention, [137](chapter-7.md#foote-ex-governor-of-mississippi-liberal-measure-of-presented-to-vicksburg-convention)
# Fort Chartres, slaves of, [6](chapter-1.md#fort-chartres-slaves-of)
# Forten, James, a wealthy Negro, [89](chapter-5.md#forten-james-a-wealthy-negro)
#
# Freedman’s relief societies, aid of, [111–112](chapter-6.md#freedmans-relief-societies-aid-of)
# Free Negroes, opposed to American Colonization Society, [65–66](chapter-4.md#free-negroes-opposed-to-american-colonization-society); interested in African colonization, [67–68](chapter-4.md#interested-in-african-colonization); National Council of, [79](chapter-4.md#national-council-of)
# French, departure of, from West to keep slaves, [7](chapter-1.md#french-departure-of-from-west-to-keep-slaves); welcome of, to fugitive slaves of the English colonies, [11](chapter-1.md#welcome-of-to-fugitive-slaves-of-the-english-colonies); good treatment of, [12](chapter-1.md#good-treatment-of); Friends of fugitives, [30](chapter-2.md#friends-of-fugitives)
# Fugitive Slave Law, a destroyer of Negro settlements, [82](chapter-5.md#fugitive-slave-law-a-destroyer-of-negro-settlements)
# Fugitives coming to Pennsylvania, [41](chapter-3.md#fugitives-coming-to-pennsylvania)
#
# Gallipolis, friends of fugitives in, [30](chapter-2.md#gallipolis-friends-of-fugitives-in)
# Georgia, laws of, against Negro mechanics, [84](chapter-5.md#georgia-laws-of-against-negro-mechanics); slavery considered profitable in, [2](chapter-1.md#slavery-considered-profitable-in)
# Germans antagonistic to Negroes, [41](chapter-3.md#germans-antagonistic-to-negroes); favorable to fugitives in mountains, [31](chapter-2.md#favorable-to-fugitives-in-mountains); opposed Negro settlement in Mercer County, Ohio, [26–27](chapter-2.md#opposed-negro-settlement-in-mercer-county-ohio); their hatred of Negroes, [82](chapter-5.md#their-hatred-of-negroes)
# Gibbs, Judge M. W., went from Philadelphia to Arkansas, [124](chapter-6.md#gibbs-judge-m-w-went-from-philadelphia-to-arkansas)
# Gilmore’s High School, work of, in Cincinnati, [94](chapter-5.md#gilmores-high-school-work-of-in-cincinnati)
# Gist, Samuel, settled his Negroes in Ohio, [25](chapter-2.md#gist-samuel-settled-his-negroes-in-ohio)
# Goodrich, William, owner of railroad stock, [90](chapter-5.md#goodrich-william-owner-of-railroad-stock)
# Gordon, Robert, a successful coal dealer in Cincinnati, [95–96](chapter-5.md#gordon-robert-a-successful-coal-dealer-in-cincinnati)
# Grant, General U. S., protected refugees in his camp, [103](chapter-6.md#grant-general-u-s-protected-refugees-in-his-camp); retained them at Fort Donelson, [103](chapter-6.md#retained-them-at-fort-donelson); his use of the refugees, [109](chapter-6.md#his-use-of-the-refugees)
# Greener, R. T., comment of, on the exodus to Kansas, [139–141](chapter-7.md#greener-r-t-comment-of-on-the-exodus-to-kansas); went from Philadelphia to South Carolina, [124](chapter-6.md#went-from-philadelphia-to-south-carolina)
# Gregg, Theodore H., sent his manumitted slaves to Ohio, [27](chapter-2.md#gregg-theodore-h-sent-his-manumitted-slaves-to-ohio)
# Gulf States, proposed Negro commonwealths of, [147](chapter-8.md#gulf-states-proposed-negro-commonwealths-of)
# Guild of Caterers, in Philadelphia, [89](chapter-5.md#guild-of-caterers-in-philadelphia)
#
# Halleck, General, excluded slaves from his lines, [102](chapter-6.md#halleck-general-excluded-slaves-from-his-lines)
# Harlan, Robert, a horseman, [95](chapter-5.md#harlan-robert-a-horseman)
# Harper, John, sent his slaves to Mercer County, Ohio, [26](chapter-2.md#harper-john-sent-his-slaves-to-mercer-county-ohio)
# Harrisburg, Negroes in, [24](chapter-2.md#harrisburg-negroes-in); reaction against Negroes in, [44](chapter-3.md#reaction-against-negroes-in)
# Harrison, President William H., accommodated at the café of John Julius, a Negro, [90](chapter-5.md#harrison-president-william-h-accommodated-at-the-cafe-of-john-julius-a-negro)
# Hayden, a successful clothier, [85](chapter-5.md#hayden-a-successful-clothier)
# Hayti, the exodus of Negroes to, 74–76, [79–80](chapter-4.md#hayti-the-exodus-of-negroes-to-74-76)
# Henry, Patrick, on natural rights, [1](chapter-1.md#henry-patrick-on-natural-rights)
# Hill of Chillicothe, a tanner and currier, [92](chapter-5.md#hill-of-chillicothe-a-tanner-and-currier)
# Holly, James T., interest of, in colonization, [79](chapter-4.md#holly-james-t-interest-of-in-colonization)
# Hood, James W., went from Connecticut to North Carolina, [124](chapter-6.md#hood-james-w-went-from-connecticut-to-north-carolina)
# Hunter, General, dealing with the refugees in South Carolina, [109](chapter-6.md#hunter-general-dealing-with-the-refugees-in-south-carolina)
#
# Illinois, the attitude of, toward the Negro, [54](chapter-3.md#illinois-the-attitude-of-toward-the-negro); race prejudice in, [50](chapter-3.md#race-prejudice-in); slavery question in the organization of, [14](chapter-1.md#slavery-question-in-the-organization-of); effort to make the constitution proslavery, [15](chapter-1.md#effort-to-make-the-constitution-proslavery)
#
# Immigration of foreigners, cessation of, a cause of the Negro migration, [172-173](chapter-9.md#immigration-of-foreigners-cessation-of-a-cause-of-the-negro-migration)
# Indian Territory, exodus of Negroes to, [143](chapter-7.md#indian-territory-exodus-of-negroes-to)
# Indiana, the attitude of, toward the Negro, [53](chapter-3.md#indiana-the-attitude-of-toward-the-negro); counties of, receiving Negroes from slave states, [24](chapter-2.md#counties-of-receiving-negroes-from-slave-states); slavery question in the organization of, [14](chapter-1.md#slavery-question-in-the-organization-of); effort to make constitution of proslavery, [15](chapter-1.md#effort-to-make-constitution-of-proslavery); race prejudice in, [58](chapter-3.md#race-prejudice-in); protest against the settlement of Negroes there, [58-59](chapter-3.md#protest-against-the-settlement-of-negroes-there)
# Indians, attitude of, toward the Negroes, 144, 145, [146](chapter-7.md#indians-attitude-of-toward-the-negroes-144-145)
# Infirmary Farms, for refugees, [106](chapter-6.md#infirmary-farms-for-refugees)
# Intimidation, a cause of migration, [156](chapter-8.md#intimidation-a-cause-of-migration)
# Irish, antagonistic to Negroes, [41](chapter-3.md#irish-antagonistic-to-negroes); their hatred of Negroes, [82](chapter-5.md#their-hatred-of-negroes)
#
# Jamaica, Negroes of the United States settled in, [78-79](chapter-4.md#jamaica-negroes-of-the-united-states-settled-in)
# Jay’s Treaty, [8](chapter-1.md#jays-treaty)
# Jefferson, Thomas, his plan for general education including the slaves, [9](chapter-1.md#jefferson-thomas-his-plan-for-general-education-including-the-slaves); plan to colonize Negroes in the West, [9-10](chapter-1.md#plan-to-colonize-negroes-in-the-west); natural rights theory of, [1](chapter-1.md#natural-rights-theory-of); an advocate of the colonization of the Negroes in the West Indies, 68-69*Jenking, David, a paper hanger and glazier, [92](chapter-5.md#an-advocate-of-the-colonization-of-the-negroes-in-the-west-indies-68-69-jenking-david-a-paper-hanger-and-glazier)
# Johnson General, permitted slave hunters to seek their slaves in his lines, [102](chapter-6.md#johnson-general-permitted-slave-hunters-to-seek-their-slaves-in-his-lines)
# Julius, John, proprietor of a café in which he entertained President William H. Harrison, [90](chapter-5.md#julius-john-proprietor-of-a-cafe-in-which-he-entertained-president-william-h-harrison)
#
# Kansas Freedmen’s Relief Association, the work of, [141](chapter-7.md#kansas-freedmens-relief-association-the-work-of)
# Kansas refugees, condition of, [142](chapter-7.md#kansas-refugees-condition-of); treatment of, [142-143](chapter-7.md#treatment-of)
# Kaskokia, slaves of, [6](chapter-1.md#kaskokia-slaves-of)
# Keith, George, interested in the Negroes, [20](chapter-2.md#keith-george-interested-in-the-negroes)
# Kentucky, disfranchisement of Negroes in, [39](chapter-3.md#kentucky-disfranchisement-of-negroes-in); abolition society of, advocated the colonization of the blacks in the West, [10](chapter-1.md#abolition-society-of-advocated-the-colonization-of-the-blacks-in-the-west)
# Key, Francis S., a colonizationist, [63](chapter-4.md#key-francis-s-a-colonizationist)
# Kingsley, Z., a master, settled his son of color in Hayti, [75-77](chapter-4.md#kingsley-z-a-master-settled-his-son-of-color-in-hayti)
# Ku Klux Klan, the work of, [128](chapter-7.md#ku-klux-klan-the-work-of)
#
# Labor agentspromoting the migration of Negroes, [173-174](chapter-9.md#labor-agentspromoting-the-migration-of-negroes)
# Lambert, William, interest of, in the colonization of Negroes, [79](chapter-4.md#lambert-william-interest-of-in-the-colonization-of-negroes)
# Land tenure, a cause of unrest, 131, 133, [134](chapter-7.md#land-tenure-a-cause-of-unrest-131-133); after Reconstruction, [131-132](chapter-7.md#after-reconstruction)
# Langston, John M., returned from Ohio to Virginia, [124](chapter-6.md#langston-john-m-returned-from-ohio-to-virginia)
# Lawrence County, Ohio, Negroes immigrated into, [57](chapter-3.md#lawrence-county-ohio-negroes-immigrated-into)
# Liberia, freedmen sent to, [22](chapter-2.md#liberia-freedmen-sent-to)
# Lincoln, Abraham, urged withholding slaves, [103](chapter-6.md#lincoln-abraham-urged-withholding-slaves)
# Louis XIV, slave regulations of, [7](chapter-1.md#louis-xiv-slave-regulations-of)
# Louisiana, drain of laborers to, [120](chapter-6.md#louisiana-drain-of-laborers-to); exodus from, [134](chapter-7.md#exodus-from); refugees in, [106](chapter-6.md#refugees-in)
# Lower Camps, Brown County, Negroes of, [25](chapter-2.md#lower-camps-brown-county-negroes-of)
# Lower Louisiana, conditions of, [7](chapter-1.md#lower-louisiana-conditions-of); conditions of slaves in, [7](chapter-1.md#conditions-of-slaves-in)
# Lundy, Benjamin, promoter of the migration of Negroes, [35](chapter-2.md#lundy-benjamin-promoter-of-the-migration-of-negroes)
# Lynching, a cause of migration, 128–129, [156](chapter-8.md#lynching-a-cause-of-migration-128-129); number of Negroes lynched, [156](chapter-8.md#number-of-negroes-lynched)
#
# McCook, General, permitted slave hunters to seek their Negroes in his lines, [102](chapter-6.md#mccook-general-permitted-slave-hunters-to-seek-their-negroes-in-his-lines)
# Maryland, disfranchisement of Negroes in, [39](chapter-3.md#maryland-disfranchisement-of-negroes-in); passed laws against Negro mechanics, [84](chapter-5.md#passed-laws-against-negro-mechanics); reaction in, [2](chapter-1.md#reaction-in)
# Massachusetts exterminated slavery, [2](chapter-1.md#massachusetts-exterminated-slavery)
#
# Meade, Bishop William, a colonizationist, [63](chapter-4.md#meade-bishop-william-a-colonizationist)
# Mercer County, Ohio, successful Negroes of, [93](chapter-5.md#mercer-county-ohio-successful-negroes-of); resolutions of citizens against Negroes, [56](chapter-3.md#resolutions-of-citizens-against-negroes)
# Miami County, Randolph’s Negroes sent to, [27](chapter-2.md#miami-county-randolphs-negroes-sent-to)
# Michigan, Negroes transplanted to, [27](chapter-2.md#michigan-negroes-transplanted-to); attitude of, toward the Negro, [54](chapter-3.md#attitude-of-toward-the-negro)
# Migration, the, of the talented tenth, [147–166](chapter-8.md#migration-the-of-the-talented-tenth); handicaps of, 165, [166](chapter-8.md#handicaps-of-165); of politicians to Washington, [160](chapter-8.md#of-politicians-to-washington); of the educated Negroes, [161](chapter-8.md#of-the-educated-negroes); of the intelligent laboring class, [162](chapter-8.md#of-the-intelligent-laboring-class); effect of Negroes’ prospective political power, [163](chapter-8.md#effect-of-negroes-prospective-political-power); to northern cities, 85, [163](chapter-8.md#to-northern-cities-85)
# Miles, N. R., interest in stopping the exodus to Kansas, [135](chapter-7.md#miles-n-r-interest-in-stopping-the-exodus-to-kansas)
# Mississippi, drain of laborers to, [120](chapter-6.md#mississippi-drain-of-laborers-to); exodus from, [134](chapter-7.md#exodus-from); refugees in, [106](chapter-6.md#refugees-in); slaves along, [6](chapter-1.md#slaves-along)
# Morgan, Senator, of Alabama, interested in sending the Negroes to Africa, [148](chapter-8.md#morgan-senator-of-alabama-interested-in-sending-the-negroes-to-africa)
# Movement of the blacks to the western territory, [18](chapter-2.md#movement-of-the-blacks-to-the-western-territory); promoted by Quakers, [18](chapter-2.md#promoted-by-quakers)
# Movements of Negroes during the Civil War, [101–124](chapter-6.md#movements-of-negroes-during-the-civil-war); of poor whites, [101](chapter-6.md#of-poor-whites)
# Mulber, Stephen, a contractor, [91](chapter-5.md#mulber-stephen-a-contractor)
# Murder of Negroes in the South, [128–129](chapter-7.md#murder-of-negroes-in-the-south)
#
# Natural rights, the effect of the discussion of, on the condition of the Negro, [1–2](chapter-1.md#natural-rights-the-effect-of-the-discussion-of-on-the-condition-of-the-negro)
# Negro journalists, the number of, [98](chapter-5.md#negro-journalists-the-number-of)
# Negroes, condition of, after Reconstruction, [126-129](chapter-7.md#negroes-condition-of-after-reconstruction); escaped to the West, [11](chapter-1.md#escaped-to-the-west); those having wealth tend to remain in the South, [160](chapter-8.md#those-having-wealth-tend-to-remain-in-the-south); migration of, to Mexico, [151](chapter-8.md#migration-of-to-mexico); exodus of, to Liberia, [157](chapter-8.md#exodus-of-to-liberia); no freedom of speech of, [165](chapter-8.md#no-freedom-of-speech-of); not migratory, [121](chapter-6.md#not-migratory); leaders of Reconstruction, largely from the North, [123](chapter-6.md#leaders-of-reconstruction-largely-from-the-north); mechanics in Cincinnati, [94–95](chapter-5.md#mechanics-in-cincinnati); servants on Ohio river vessels, [94](chapter-5.md#servants-on-ohio-river-vessels)
# New Hampshire, exterminated slavery, [2](chapter-1.md#new-hampshire-exterminated-slavery)
# New Jersey, abolished slavery, [2](chapter-1.md#new-jersey-abolished-slavery)
# New York, abolition of slavery in, [2](chapter-1.md#new-york-abolition-of-slavery-in); friends of fugitives in, [31](chapter-2.md#friends-of-fugitives-in); mobs of, attack Negroes, [48](chapter-3.md#mobs-of-attack-negroes); Negro suffrage in, [40](chapter-3.md#negro-suffrage-in); restrictions of, on Negroes, [48–49](chapter-3.md#restrictions-of-on-negroes)
# North Carolina, Negro suffrage in, [39–40](chapter-3.md#north-carolina-negro-suffrage-in); Quakers of, promoting the migration of the Negroes, 18–19, 21, [22](chapter-2.md#quakers-of-promoting-the-migration-of-the-negroes-18-19-21); reaction in, [2](chapter-1.md#reaction-in)
# North, change in attitude of, toward the Negro, [100](chapter-5.md#north-change-in-attitude-of-toward-the-negro); divided in its sentiment as to method of helping the Negro, [83](chapter-5.md#divided-in-its-sentiment-as-to-method-of-helping-the-negro); favorable sentiment of, [3](chapter-1.md#favorable-sentiment-of); trade of, with the South, [3](chapter-1.md#trade-of-with-the-south); fugitives not generally welcomed, [3](chapter-1.md#fugitives-not-generally-welcomed); its Negro problem, [186](chapter-9.md#its-negro-problem); housing the Negro in, [186–187](chapter-9.md#housing-the-negro-in); criminal class of Negroes in, 188, [189](chapter-9.md#criminal-class-of-negroes-in-188); loss of interest in the Negro, [157](chapter-8.md#loss-of-interest-in-the-negro); not a place of refuge for Negroes, [16](chapter-1.md#not-a-place-of-refuge-for-negroes)
# Northwest, few Negroes in, at first, [17](chapter-1.md#northwest-few-negroes-in-at-first); hesitation to go there because of the ordinance of 87, [17](chapter-1.md#hesitation-to-go-there-because-of-the-ordinance-of-87)
# Noyes Academy broken up because it admitted Negroes, [49](chapter-3.md#noyes-academy-broken-up-because-it-admitted-negroes)
# Nugent, Colonel W. L., interest in stopping the exodus to Kansas, [135](chapter-7.md#nugent-colonel-w-l-interest-in-stopping-the-exodus-to-kansas)
#
# Occupations of Negroes in the North, [190–191](chapter-9.md#occupations-of-negroes-in-the-north)
# Ohio, Negro question in constitutional convention of, [51](chapter-3.md#ohio-negro-question-in-constitutional-convention-of); in the legislature of 1804, [51](chapter-3.md#in-the-legislature-of-1804); black laws of, [51–53](chapter-3.md#black-laws-of); protest against Negroes, [57](chapter-3.md#protest-against-negroes)
# Oklahoma, Negroes in, [144](chapter-7.md#oklahoma-negroes-in); discouraged by early settlers of, [144–145](chapter-7.md#discouraged-by-early-settlers-of)
# Ordinance of 178 rejected, [4](chapter-1.md#ordinance-of-178-rejected); Ordinance of 1787 passed, [4](chapter-1.md#ordinance-of-1787-passed); meaning of sixth article of, 4, [5](chapter-1.md#meaning-of-sixth-article-of-4); reasons for the passage of, [5](chapter-1.md#reasons-for-the-passage-of); did not at first disturb slavery, [8](chapter-1.md#did-not-at-first-disturb-slavery); construction of, 8–9, [18](chapter-2.md#construction-of-8-9)
# Otis, James, on natural rights, [1](chapter-1.md#otis-james-on-natural-rights)
#
# Pacific Railroad, proposal to build, with refugee labor, [113](chapter-6.md#pacific-railroad-proposal-to-build-with-refugee-labor)
# Palmyra, race prejudice of, [49](chapter-3.md#palmyra-race-prejudice-of)
# Pelham, Robert A., father of, moved to Detroit, 27, [97](chapter-5.md#pelham-robert-a-father-of-moved-to-detroit-27)
# Penn, William, advocate of emancipation, [20](chapter-2.md#penn-william-advocate-of-emancipation)
# Pennsylvania, effort in to force free Negroes to support their dependents, [42](chapter-3.md#pennsylvania-effort-in-to-force-free-negroes-to-support-their-dependents); effort to prevent immigration of Negroes, [42](chapter-3.md#effort-to-prevent-immigration-of-negroes); increase in the population of free Negroes of, [42](chapter-3.md#increase-in-the-population-of-free-negroes-of); petitions to rid the State of Negroes by colonization, [45](chapter-3.md#petitions-to-rid-the-state-of-negroes-by-colonization); era of good feeling in, [40](chapter-3.md#era-of-good-feeling-in); exterminated slavery, [2](chapter-1.md#exterminated-slavery); the migration of freedmen from North Carolina to, [21](chapter-2.md#the-migration-of-freedmen-from-north-carolina-to); Negro suffrage in, [40](chapter-3.md#negro-suffrage-in); passed laws against Negro mechanic, [84](chapter-5.md#passed-laws-against-negro-mechanic); successful Negroes of, [88–90](chapter-5.md#successful-negroes-of)
# Peonage, a cause of migration, [154](chapter-8.md#peonage-a-cause-of-migration)
# Philadelphia, Negroes rush to, [24](chapter-2.md#philadelphia-negroes-rush-to); race friction of, [44](chapter-3.md#race-friction-of); woman of color stoned to death, [44](chapter-3.md#woman-of-color-stoned-to-death); Negro church disturbed, [44](chapter-3.md#negro-church-disturbed); reaction against Negroes, [44](chapter-3.md#reaction-against-negroes); riots in, [45–48](chapter-3.md#riots-in); successful Negroes of, [88–90](chapter-5.md#successful-negroes-of); property owned by Negroes, [89](chapter-5.md#property-owned-by-negroes)
# Pierce, E. S., plan for handling refugees in South Carolina, [102](chapter-6.md#pierce-e-s-plan-for-handling-refugees-in-south-carolina)
# Pineback, P. B. S., return of, from Ohio to Louisiana to enter politics, [125](chapter-6.md#pineback-p-b-s-return-of-from-ohio-to-louisiana-to-enter-politics)
# Pittman, Philip, account of West, of, [7](chapter-1.md#pittman-philip-account-of-west-of)
# Pittsburgh, friends of fugitives in, [30](chapter-2.md#pittsburgh-friends-of-fugitives-in); Negro of, married to French woman, [12](chapter-1.md#negro-of-married-to-french-woman); kind treatment of refugees, [12](chapter-1.md#kind-treatment-of-refugees); respectable mulatto woman married to a surgeon of Nantes, [12](chapter-1.md#respectable-mulatto-woman-married-to-a-surgeon-of-nantes); riot in, [47](chapter-3.md#riot-in)
# Platt, William, a lumber merchant, [87](chapter-5.md#platt-william-a-lumber-merchant)
# Political power, not to be the only aim of the migrants, [181](chapter-9.md#political-power-not-to-be-the-only-aim-of-the-migrants); the mistakes of such a policy, [181–183](chapter-9.md#the-mistakes-of-such-a-policy)
# Politics, a cause of unrest, [153](chapter-8.md#politics-a-cause-of-unrest)
# Pollard, N. W., agent of the Government of Trinidad, sought Negroes in the United States, [78](chapter-4.md#pollard-n-w-agent-of-the-government-of-trinidad-sought-negroes-in-the-united-states)
# Portsmouth, friends of fugitives out of, [30](chapter-2.md#portsmouth-friends-of-fugitives-out-of)
# Portsmouth, Ohio, mob of, drives Negroes out, [57](chapter-3.md#portsmouth-ohio-mob-of-drives-negroes-out); progressive Negroes of, [92](chapter-5.md#progressive-negroes-of)
# Prairie du Rocher, slaves of, [6](chapter-1.md#prairie-du-rocher-slaves-of)
# Press comments on sending Negroes to Africa, [148-150](chapter-8.md#press-comments-on-sending-negroes-to-africa)
# Puritans, not much interested in the Negro, [19](chapter-2.md#puritans-not-much-interested-in-the-negro)
#
# Quakers, promoted the movement of the blacks to Western territory, [18-38](chapter-2.md#quakers-promoted-the-movement-of-the-blacks-to-western-territory); in the mountains assisted fugitives, [34](chapter-2.md#in-the-mountains-assisted-fugitives)
#
# Race prejudice, the effects of, [82-83](chapter-5.md#race-prejudice-the-effects-of); among laboring classes, [82-84](chapter-5.md#among-laboring-classes)
# Randolph, John, a colonizationist, [63](chapter-4.md#randolph-john-a-colonizationist); sought to settle his slaves in Mercer County, Ohio, [26](chapter-2.md#sought-to-settle-his-slaves-in-mercer-county-ohio)
# Reaction against the Negro, [20](chapter-2.md#reaction-against-the-negro)
# Reconstruction, promoted to an extent by Negro natives of North, [123](chapter-6.md#reconstruction-promoted-to-an-extent-by-negro-natives-of-north)
# Redpath, James, interest of, in colonization, [80](chapter-4.md#redpath-james-interest-of-in-colonization)
# Refugees assembled in camps, [105-106](chapter-6.md#refugees-assembled-in-camps); in West, [106](chapter-6.md#in-west); in Washington, [155](chapter-8.md#in-washington); in South, [106](chapter-6.md#in-south); exodus of, to the North, [112](chapter-6.md#exodus-of-to-the-north); fear that they would overrun the North, [113](chapter-6.md#fear-that-they-would-overrun-the-north); development of, [116](chapter-6.md#development-of); vagrancy at close of war, [117-118](chapter-6.md#vagrancy-at-close-of-war)
# Renault, Philip Francis, imported slaves, [6](chapter-1.md#renault-philip-francis-imported-slaves)
# Resolutions of the Vicksburg Convention bearing on the exodus to Kansas, [136-137](chapter-7.md#resolutions-of-the-vicksburg-convention-bearing-on-the-exodus-to-kansas)
# Rhode Island exterminated slavery, [2](chapter-1.md#rhode-island-exterminated-slavery)
#
# Richards, Benjamin, a wealthy Negro of Pittsburgh, [90](chapter-5.md#richards-benjamin-a-wealthy-negro-of-pittsburgh)
# Richard, Fannie M., a successful teacher in Detroit, [97-98](chapter-5.md#richard-fannie-m-a-successful-teacher-in-detroit)
# Riley, William H., a well-to-do bookmaker, [90](chapter-5.md#riley-william-h-a-well-to-do-bookmaker)
# Ringold, Thomas, advertisement of, for a slave in the West, [11](chapter-1.md#ringold-thomas-advertisement-of-for-a-slave-in-the-west)
# Rochester, friends of fugitives in, [30](chapter-2.md#rochester-friends-of-fugitives-in)
#
# Saint John, Governor, aid of, to the Negroes in Kansas, [141](chapter-7.md#saint-john-governor-aid-of-to-the-negroes-in-kansas)
# Sandy Lake, Negro settlement in, [24](chapter-2.md#sandy-lake-negro-settlement-in)
# Saunders of Cabell County, Virginia, sent manumitted slaves to Cass County, Michigan, [28](chapter-2.md#saunders-of-cabell-county-virginia-sent-manumitted-slaves-to-cass-county-michigan)
# Saxon, General Rufus, plan for handling refugees in South Carolina, [102](chapter-6.md#saxon-general-rufus-plan-for-handling-refugees-in-south-carolina)
# Scotch-Irish Presbyterians, favorable to fugitives, [31](chapter-2.md#scotch-irish-presbyterians-favorable-to-fugitives)
# Scott, Henry, owner of a pickling business, [87](chapter-5.md#scott-henry-owner-of-a-pickling-business)
# Seroggs, Wm. O., referred to as authority on interstate migration, [121](chapter-6.md#seroggs-wm-o-referred-to-as-authority-on-interstate-migration)
# Segregation, a cause of migration, [157](chapter-8.md#segregation-a-cause-of-migration)
# Shelby County, Ohio, Negroes in, [24](chapter-2.md#shelby-county-ohio-negroes-in)
# Sierra Leone, Negroes of, settled in Jamaica, [79](chapter-4.md#sierra-leone-negroes-of-settled-in-jamaica)
# Simmons, W. J., returned from Pennsylvania to Kentucky, [124](chapter-6.md#simmons-w-j-returned-from-pennsylvania-to-kentucky)
# Singleton, Moses, leader of the exodus from Kansas, [135](chapter-7.md#singleton-moses-leader-of-the-exodus-from-kansas)
# Sixth Article of Ordinance of 1787, [4-5](chapter-1.md#sixth-article-of-ordinance-of-1787)
# Slave Code in Louisiana, [7](chapter-1.md#slave-code-in-louisiana)
# Slavery in the Northwest, 5, 6, [7](chapter-1.md#slavery-in-the-northwest-5-6); slavery in Indiana, [5](chapter-1.md#slavery-in-indiana); slavery of whites, [5](chapter-1.md#slavery-of-whites)
# Slaves, mingled freely with their masters in early West, [7](chapter-1.md#slaves-mingled-freely-with-their-masters-in-early-west)
# Smith, Gerrit, effort to colonize Negroes in New York, [86–87](chapter-5.md#smith-gerrit-effort-to-colonize-negroes-in-new-york)
# Smith, Stephen, a lumber merchant, [89](chapter-5.md#smith-stephen-a-lumber-merchant)
# South Carolina, slavery considered profitable there, [2](chapter-1.md#south-carolina-slavery-considered-profitable-there)
# South, change of attitude of, toward the Negro, [185](chapter-9.md#south-change-of-attitude-of-toward-the-negro); drastic laws against vagrancy, [121–123](chapter-6.md#drastic-laws-against-vagrancy)
# Southern States divided on the Negro, [32–33](chapter-2.md#southern-states-divided-on-the-negro)
# Spears, Noah, sent his manumitted slaves to Greene County, Ohio, [27](chapter-2.md#spears-noah-sent-his-manumitted-slaves-to-greene-county-ohio)
# Starr, Frederick, comment of, on the refugees, [113](chapter-6.md#starr-frederick-comment-of-on-the-refugees)
# Steubenville, successful Negroes of, [91](chapter-5.md#steubenville-successful-negroes-of)
# Still, William, a coal merchant, [89–90](chapter-5.md#still-william-a-coal-merchant)
# St. Philippe, slaves of, [6](chapter-1.md#st-philippe-slaves-of)
# Success of Negro migrants, [81–101](chapter-5.md#success-of-negro-migrants)
# Suffrage of the Negroes in the colonies, [39–40](chapter-3.md#suffrage-of-the-negroes-in-the-colonies)
#
# Tappan, Arthur, attacked by New York mob, [41](chapter-3.md#tappan-arthur-attacked-by-new-york-mob)
# Tappan, Lewis, attacked by New York mob, [48](chapter-3.md#tappan-lewis-attacked-by-new-york-mob)
# Terrorism, a cause of migration, [177](chapter-9.md#terrorism-a-cause-of-migration)
# Texas, drain of laborers to, [120](chapter-6.md#texas-drain-of-laborers-to); proposed colony of Negroes there, [66](chapter-4.md#proposed-colony-of-negroes-there)
# Thomas, General, opened farms for refugees, [106](chapter-6.md#thomas-general-opened-farms-for-refugees)
# Thompson, A. V., a tailor, [95](chapter-5.md#thompson-a-v-a-tailor)
# Thompson, C. M., comment on freedmen's vagrancy, [118](chapter-6.md#thompson-c-m-comment-on-freedmen-s-vagrancy)
# Topp, W. H., a merchant tailor, [82](chapter-5.md#topp-w-h-a-merchant-tailor)
# Trades unions, attitude of, toward Negro labor, [190–192](chapter-9.md#trades-unions-attitude-of-toward-negro-labor)
# Trinidad, the exodus of Negroes to, [77–88](chapter-4.md#trinidad-the-exodus-of-negroes-to); Negroes from Philadelphia settled there, [78](chapter-4.md#negroes-from-philadelphia-settled-there)
# Turner, Bishop H. M., interested in sending Negroes to Africa, [157](chapter-8.md#turner-bishop-h-m-interested-in-sending-negroes-to-africa)
#
# Upper and Lower Camps of Brown County, Ohio, Negroes of, [25](chapter-2.md#upper-and-lower-camps-of-brown-county-ohio-negroes-of)
# Upper Louisiana, conditions of, [7](chapter-1.md#upper-louisiana-conditions-of); conditions of slaves in, [7](chapter-1.md#conditions-of-slaves-in)
#
# Unrest of the Negroes in the South after Reconstruction, [126–130](chapter-7.md#unrest-of-the-negroes-in-the-south-after-reconstruction); causes of, 127–129, [130](chapter-7.md#causes-of-127-129); credit system a cause, [131](chapter-7.md#credit-system-a-cause); land system a cause, [132](chapter-7.md#land-system-a-cause); further unrest of, intelligent Negroes, 152, [153](chapter-8.md#further-unrest-of-intelligent-negroes-152)
# Tito, mob of, attacked anti-slavery leaders, [48](chapter-3.md#tito-mob-of-attacked-anti-slavery-leaders)
#
# Vagrancy of Negroes after emancipation, [111–119](chapter-6.md#vagrancy-of-negroes-after-emancipation); drastic legislation against, [121–123](chapter-6.md#drastic-legislation-against)
# Vermont, exterminated slavery, [2](chapter-1.md#vermont-exterminated-slavery)
# Vicksburg, Convention of, to stop the Exodus, [135](chapter-7.md#vicksburg-convention-of-to-stop-the-exodus)
# Viner, M., mentioned slave settlements in West, [6](chapter-1.md#viner-m-mentioned-slave-settlements-in-west)
# Virginia, disfranchisement of Negroes in, [39](chapter-3.md#virginia-disfranchisement-of-negroes-in); Quakers of, promoting the migration of the Negroes, [18–19](chapter-2.md#quakers-of-promoting-the-migration-of-the-negroes); reaction in, [2](chapter-1.md#reaction-in); refugees in, [106](chapter-6.md#refugees-in)
# Voorhees, Senator D. W., offered a resolution in Senate inquiring into the exodus to Kansas, [138](chapter-7.md#voorhees-senator-d-w-offered-a-resolution-in-senate-inquiring-into-the-exodus-to-kansas)
#
# Washington, Judge Bushrod, a colonizationist, [63](chapter-4.md#washington-judge-bushrod-a-colonizationist)
# Washington, D. C., refugees in, [105](chapter-6.md#washington-d-c-refugees-in); the migration of Negro politicians to, [160](chapter-8.md#the-migration-of-negro-politicians-to)
# Wattles, Augustus, settled with Negros in Mercer County, Ohio, [25-26](chapter-2.md#wattles-augustus-settled-with-negros-in-mercer-county-ohio)
# Watts, steam engine and the industrial revolution, [2](chapter-1.md#watts-steam-engine-and-the-industrial-revolution)
# Wayne County, Indiana, freedmen settled in, [23](chapter-2.md#wayne-county-indiana-freedmen-settled-in)
# Webb, William, interest of, in colonization, [79](chapter-4.md#webb-william-interest-of-in-colonization)
# Wenyam, James, ran away to the West, [11](chapter-1.md#wenyam-james-ran-away-to-the-west)
# West Indies, attractive to free Negroes, [68](chapter-4.md#west-indies-attractive-to-free-negroes)
# West Virginia, exodus of Negroes to, [146](chapter-7.md#west-virginia-exodus-of-negroes-to)
# White, David, led a company of Negroes to the Northwest, [22-23](chapter-2.md#white-david-led-a-company-of-negroes-to-the-northwest)
# White, J. T., left Indiana to enter politics in Arkansas, [124](chapter-6.md#white-j-t-left-indiana-to-enter-politics-in-arkansas)
# Whites of South refused to work, [127-128](chapter-7.md#whites-of-south-refused-to-work)
# Whitfield, James M., interest of, in colonization, [79](chapter-4.md#whitfield-james-m-interest-of-in-colonization)
# Whitney's cotton gin and the industrial revolution, [2](chapter-1.md#whitney-s-cotton-gin-and-the-industrial-revolution)
# Wickham, executor of Samuel Gist, settled Gist's Negroes in Ohio, [25](chapter-2.md#wickham-executor-of-samuel-gist-settled-gist-s-negroes-in-ohio)
# Wilberforce University, established at a slave settlement, [27](chapter-2.md#wilberforce-university-established-at-a-slave-settlement)
# Wilcox, Samuel T., a merchant of Cincinnati, [95](chapter-5.md#wilcox-samuel-t-a-merchant-of-cincinnati)
#
# Yankees, comment of, on Negro labor, [115-116](chapter-6.md#yankees-comment-of-on-negro-labor)
# York, Negroes of, [24](chapter-2.md#york-negroes-of); trouble with the Negroes of, [44](chapter-3.md#trouble-with-the-negroes-of)

# %%
with open('index.md' ,'w') as outfile:
    outfile.write(index_md)

# %%
# !pwd
# Out:
# /Users/nealcaren/Documents/GitHub/notes/posts/function-calling
